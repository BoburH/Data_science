# %% [markdown]
# <a href="https://colab.research.google.com/github/BoburH/Data_science/blob/main/2_1_3_Math%26Stat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Matematik va statistik hisolash usullari

# %%
import numpy as np

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# data
arr = np.random.randn(5, 4)     # (5, 4) o'lchovli massiv (random)
arr
# Out:
# array([[-1.35106762, -0.7978912 , -0.5979442 ,  1.50482225],
#        [ 0.45080605, -1.07142417,  0.64280935,  0.39398247],
#        [ 0.4401708 , -0.44478125, -2.42015118, -0.80214269],
#        [-1.92499312, -1.89234297, -1.63233836, -0.61327182],
#        [ 1.494317  ,  0.41162096,  0.00755276,  0.51989849]])

# %% [markdown]
# # *sum* metodi

# %%
arr.sum()     # sum metodi, arr massivining barcha elementlari yig'indisini hisoblab beradi
# Out:
# -7.682368455876046

# %%
np.sum(arr)     # bu usul ham arr massivining yig'indisini hisoblaydi.
# Out:
# -7.682368455876046

# %%
arr.sum(axis=1)     # qatorlar yig'indisini hisoblaydi
# Out:
# array([-1.24208077,  0.4161737 , -3.22690432, -6.06294628,  2.43338921])

# %%
arr.sum(axis=0)      # ustunlar yig'indisini hisoblaydi
# Out:
# array([-0.89076689, -3.79481862, -4.00007164,  1.0032887 ])

# %% [markdown]
# # *mean* metodi

# %%
# mean o'zbek tilida o'rta arifmetik qiymatni ifodalaydi
# sodda ma'lumot
data = np.arange(5)   # 0-5 gacha elemtn
data
# Out:
# array([0, 1, 2, 3, 4])

# %%
mean = np.sum(data)/len(data)
mean
# Out:
# 2.0

# %%
# numpy mean
np.mean(data)
# Out:
# 2.0

# %%
data.mean()
# Out:
# 2.0

# %%
arr
# Out:
# array([[-1.35106762, -0.7978912 , -0.5979442 ,  1.50482225],
#        [ 0.45080605, -1.07142417,  0.64280935,  0.39398247],
#        [ 0.4401708 , -0.44478125, -2.42015118, -0.80214269],
#        [-1.92499312, -1.89234297, -1.63233836, -0.61327182],
#        [ 1.494317  ,  0.41162096,  0.00755276,  0.51989849]])

# %%
np.mean(arr)
# Out:
# -0.38411842279380226

# %%
np.mean(arr, axis=1)
# Out:
# array([-0.31052019,  0.10404342, -0.80672608, -1.51573657,  0.6083473 ])

# %%
arr.mean(axis=1)
# Out:
# array([-0.31052019,  0.10404342, -0.80672608, -1.51573657,  0.6083473 ])

# %%
arr.mean(axis=0)
# Out:
# array([-0.17815338, -0.75896372, -0.80001433,  0.20065774])

# %% [markdown]
# # *cumsum*  kumulyativ summa bu yig'ib boruvchi yig'indi

# %%
np.cumsum(data)
# Out:
# array([ 0,  1,  3,  6, 10])

# %%
data.cumsum()
# Out:
# array([ 0,  1,  3,  6, 10])

# %%
np.cumsum(arr)
# Out:
# array([ -1.35106762,  -2.14895882,  -2.74690302,  -1.24208077,
#         -0.79127472,  -1.86269889,  -1.21988954,  -0.82590707,
#         -0.38573627,  -0.83051751,  -3.25066869,  -4.05281138,
#         -5.9778045 ,  -7.87014748,  -9.50248584, -10.11575766,
#         -8.62144066,  -8.2098197 ,  -8.20226695,  -7.68236846])

# %%
arr.cumsum()
# Out:
# array([ -1.35106762,  -2.14895882,  -2.74690302,  -1.24208077,
#         -0.79127472,  -1.86269889,  -1.21988954,  -0.82590707,
#         -0.38573627,  -0.83051751,  -3.25066869,  -4.05281138,
#         -5.9778045 ,  -7.87014748,  -9.50248584, -10.11575766,
#         -8.62144066,  -8.2098197 ,  -8.20226695,  -7.68236846])
